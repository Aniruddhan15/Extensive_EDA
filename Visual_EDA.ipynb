# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/StudentsPerformance (1).csv')

# %% [markdown]
# **EDA**

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
sns.histplot(data=df['math score'],stat='frequency',cbar=True)
# Out:
# <Axes: xlabel='math score', ylabel='Frequency'>

# %%
len(df['parental level of education'].unique())
# Out:
# 6

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df['Total'] = df['math score']+df['reading score']+df['writing score']
df['Average']=df['Total']/3

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Total', 'Average'],
#       dtype='object')

# %%
df[df['Average']>=90]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 104    male        group C                some college      standard
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 122  female        group C                some college      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 229  female        group C                some college      standard
# 263  female        group E                 high school      standard
# 268  female        group D          associate's degree      standard
# ...

# %%
len(df[df['Average']>=80])
# Out:
# 198

# %%
len(df['Average'])
# Out:
# 1000

# %%
df['Percentage']=(df['Total']/300)*100

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      Average  Percentage
# 0  72.666667   72.666667
# 1  82.333333   82.333333
# 2  92.666667   92.666667
# ...

# %% [markdown]
# Percentage of Students passed in first class - 80 or above

# %%
(len(df[df['Average']>=80])/len(df['Average']))*100
# Out:
# 19.8

# %% [markdown]
# Percentage of Students cleared the exam - 50 or above

# %%
(len(df[df['Average']>=50])/len(df['Average']))*100
# Out:
# 89.7

# %% [markdown]
# # Only 19.8% of students have secured more than 80% and passed in first class, But 89.7% of students have secured more than 50% and passed their Grade

# %%
df[df['Average']==100].groupby('gender').count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female               2                            2      2
# male                 1                            1      1
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                        2           2              2              2
# male                          1           1              1              1
#
#         Total  Average  Percentage
# gender
# female      2        2           2
# male        1        1           1

# %% [markdown]
# # out of the 3 clean scores, 2 are female and 1 is male

# %%
df[df['Average']==100]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score  Total  \
# 458                    none         100            100            100    300
# 916               completed         100            100            100    300
# 962                    none         100            100            100    300
#
#      Average  Percentage
# 458    100.0       100.0
# 916    100.0       100.0
# 962    100.0       100.0

# %% [markdown]
# Only 3 of 1000 have clean 100% in their Grade

# %%
df[df['Total']>=250].groupby('gender').count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female              91                           91     91
# male                48                           48     48
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                       91          91             91             91
# male                         48          48             48             48
#
#         Total  Average  Percentage
# gender
# female     91       91          91
# male       48       48          48

# %% [markdown]
# 91 female dominates 48 male in having total scores >=250

# %%
df[df['Average']>=80].groupby('gender').count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             118                          118    118
# male                80                           80     80
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                      118         118            118            118
# male                         80          80             80             80
#
#         Total  Average  Percentage
# gender
# female    118      118         118
# male       80       80          80

# %% [markdown]
# Race and gender wise first class distrubution

# %%
df[df['Average']>=80].groupby(['race/ethnicity','gender']).count()
# Out:
#                        parental level of education  lunch  \
# race/ethnicity gender
# group A        female                            5      5
#                male                              6      6
# group B        female                           20     20
#                male                             15     15
# group C        female                           36     36
#                male                             19     19
# group D        female                           32     32
#                male                             21     21
# group E        female                           25     25
#                male                             19     19
#
#                        test preparation course  math score  reading score  \
# race/ethnicity gender
# group A        female                        5           5              5
#                male                          6           6              6
# ...

# %% [markdown]
# Race Wise first class students distribution

# %%
df[df['Average']>=80].groupby(['race/ethnicity']).count()
# Out:
#                 gender  parental level of education  lunch  \
# race/ethnicity
# group A             11                           11     11
# group B             35                           35     35
# group C             55                           55     55
# group D             53                           53     53
# group E             44                           44     44
#
#                 test preparation course  math score  reading score  \
# race/ethnicity
# group A                              11          11             11
# group B                              35          35             35
# group C                              55          55             55
# group D                              53          53             53
# group E                              44          44             44
#
#                 writing score  Total  Average  Percentage
# race/ethnicity
# group A                    11     11       11          11
# ...

# %%
df[df['Average']>=80].groupby(['test preparation course']).count()
# Out:
#                          gender  race/ethnicity  parental level of education  \
# test preparation course
# completed                   107             107                          107
# none                         91              91                           91
#
#                          lunch  math score  reading score  writing score  \
# test preparation course
# completed                  107         107            107            107
# none                        91          91             91             91
#
#                          Total  Average  Percentage
# test preparation course
# completed                  107      107         107
# none                        91       91          91

# %%
df[df['test preparation course']=='completed'].count()
# Out:
# gender                         358
# race/ethnicity                 358
# parental level of education    358
# lunch                          358
# test preparation course        358
# math score                     358
# reading score                  358
# writing score                  358
# Total                          358
# Average                        358
# Percentage                     358
# dtype: int64

# %%
(df[df['Average']>=80].groupby(['test preparation course']).count()/df[df['test preparation course']=='completed'].count())*100
# Out:
#                            Average  Percentage      Total     gender  \
# test preparation course
# completed                29.888268   29.888268  29.888268  29.888268
# none                     25.418994   25.418994  25.418994  25.418994
#
#                              lunch  math score  parental level of education  \
# test preparation course
# completed                29.888268   29.888268                    29.888268
# none                     25.418994   25.418994                    25.418994
#
#                          race/ethnicity  reading score  \
# test preparation course
# completed                     29.888268      29.888268
# none                          25.418994      25.418994
#
#                          test preparation course  writing score
# test preparation course
# completed                                    NaN      29.888268
# none                                         NaN      25.418994

# %% [markdown]
# 29% - secured 80 or above
# 25% - sercured 80 or abovd without test preparation course

# %% [markdown]
# # 358/1000 took the test preparation course, out of which only 29.88% have passed in first class. Hence test preparation course havent created much impact as there are 91 of them who have passed in first class with taking test preparation course
# "

# %%
df[df['test preparation course']=='none'].count()
# Out:
# gender                         642
# race/ethnicity                 642
# parental level of education    642
# lunch                          642
# test preparation course        642
# math score                     642
# reading score                  642
# writing score                  642
# Total                          642
# Average                        642
# Percentage                     642
# dtype: int64

# %%
df[df['Average']>=50].groupby(['test preparation course','gender']).count()
# Out:
#                                 race/ethnicity  parental level of education  \
# test preparation course gender
# completed               female             179                          179
#                         male               161                          161
# none                    female             300                          300
#                         male               257                          257
#
#                                 lunch  math score  reading score  \
# test preparation course gender
# completed               female    179         179            179
#                         male      161         161            161
# none                    female    300         300            300
#                         male      257         257            257
#
#                                 writing score  Total  Average  Percentage
# test preparation course gender
# completed               female            179    179      179         179
# ...

# %% [markdown]
# # Female outperforms male in those who have passed
# # Female (not completed and average>50) => 300/557, while male => 257/557
#
# #Female who have completed and total> 50 => 179/340, while male => 161/340

# %%
df[df['Average']>=50].groupby('race/ethnicity').count()
# Out:
#                 gender  parental level of education  lunch  \
# race/ethnicity
# group A             73                           73     73
# group B            163                          163    163
# group C            287                          287    287
# group D            243                          243    243
# group E            131                          131    131
#
#                 test preparation course  math score  reading score  \
# race/ethnicity
# group A                              73          73             73
# group B                             163         163            163
# group C                             287         287            287
# group D                             243         243            243
# group E                             131         131            131
#
#                 writing score  Total  Average  Percentage
# race/ethnicity
# group A                    73     73       73          73
# ...

# %%
df[df['Average']>=80].groupby('race/ethnicity').count()
# Out:
#                 gender  parental level of education  lunch  \
# race/ethnicity
# group A             11                           11     11
# group B             35                           35     35
# group C             55                           55     55
# group D             53                           53     53
# group E             44                           44     44
#
#                 test preparation course  math score  reading score  \
# race/ethnicity
# group A                              11          11             11
# group B                              35          35             35
# group C                              55          55             55
# group D                              53          53             53
# group E                              44          44             44
#
#                 writing score  Total  Average  Percentage
# race/ethnicity
# group A                    11     11       11          11
# ...

# %%
df[df['Average']>=50].count()
# Out:
# gender                         897
# race/ethnicity                 897
# parental level of education    897
# lunch                          897
# test preparation course        897
# math score                     897
# reading score                  897
# writing score                  897
# Total                          897
# Average                        897
# Percentage                     897
# dtype: int64

# %%
df[df['Average']>=80].count()
# Out:
# gender                         198
# race/ethnicity                 198
# parental level of education    198
# lunch                          198
# test preparation course        198
# math score                     198
# reading score                  198
# writing score                  198
# Total                          198
# Average                        198
# Percentage                     198
# dtype: int64

# %%
# @title math score

from matplotlib import pyplot as plt
df['math score'].plot(kind='hist', bins=20, title='math score')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['gender']= label_encoder.fit_transform(df['gender'])

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['race/ethnicity']= label_encoder.fit_transform(df['race/ethnicity'])

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['parental level of education']= label_encoder.fit_transform(df['parental level of education'])
df['lunch']= label_encoder.fit_transform(df['lunch'])
df['test preparation course']= label_encoder.fit_transform(df['test preparation course'])

# %%
df.head(10)
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       0               1                            1      1
# 1       0               2                            4      1
# 2       0               1                            3      1
# 3       1               0                            0      0
# 4       1               2                            4      1
# 5       0               1                            0      1
# 6       0               1                            4      1
# 7       1               1                            4      0
# 8       1               3                            2      0
# 9       0               1                            2      0
#
#    test preparation course  math score  reading score  writing score  Total  \
# 0                        1          72             72             74    218
# 1                        0          69             90             88    247
# ...

# %%
df.drop(['Percentage'],inplace=True,axis=1)

# %%
sns.heatmap(df.corr(),annot=True,square=1,cmap='Greens',annot_kws={'size': 7.5},linewidths=2,
                linecolor='yellow')
# Out:
# <Axes: >

# %%
df.drop(['parental level of education'],axis=1,inplace=True)

# %% [markdown]
# Univariate Analysis

# %%
fig, ax = plt.subplots(1,2,figsize=(15,10))
plt.subplot(121)
sns.histplot(data=df,x='math score',bins=40,kde=True,color='r',hue='gender')
plt.subplot(122)
sns.histplot(data=df,x='math score',bins=30,kde=True,color='b')
plt.show()

# %%
sns.barplot(y='Total',x='gender',hue='race/ethnicity',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='Total'>

# %%
sns.barplot(y='Average',hue='test preparation course',x='race/ethnicity',data=df,saturation=0.75,color='r')
# Out:
# <ipython-input-174-7d7411fd2e5d>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(y='Average',hue='test preparation course',x='race/ethnicity',data=df,saturation=0.75,color='r')
# <Axes: xlabel='race/ethnicity', ylabel='Average'>

# %%
sns.barplot(y='Average',x='test preparation course',hue='race/ethnicity',data=df,saturation=0.75,color='r')
# Out:
# <ipython-input-175-7e60168aebf0>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(y='Average',x='test preparation course',hue='race/ethnicity',data=df,saturation=0.75,color='r')
# <Axes: xlabel='test preparation course', ylabel='Average'>

# %%
sns.barplot(y='Total',hue='gender',x='race/ethnicity',data=df,saturation=0.75,color='r')
# Out:
# <ipython-input-164-9e49274471ea>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(y='Total',hue='gender',x='race/ethnicity',data=df,saturation=0.75,color='r')
# <Axes: xlabel='race/ethnicity', ylabel='Total'>

# %% [markdown]
# # Group 4 = group E have produced highest scorers among the race, and a "no brainer" that Female have outperformed the male in all races among the gender

# %% [markdown]
# Feature Selection

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
X = df.drop(['math score'],axis=1)
y=df['math score']
mut=mutual_info_classif(X,y)

# %%
md=pd.Series(mut)
md
# Out:
# 0    0.093818
# 1    0.084325
# 2    0.278854
# 3    0.088747
# 4    0.539136
# 5    0.502616
# 6    0.932042
# 7    0.921782
# dtype: float64

# %%
md=pd.Series(mut,index=X.columns)
md.sort_values(ascending=False)
# Out:
# Total                      0.932042
# Average                    0.921782
# reading score              0.539136
# writing score              0.502616
# lunch                      0.278854
# gender                     0.093818
# test preparation course    0.088747
# race/ethnicity             0.084325
# dtype: float64

# %% [markdown]
# Feature Importance using ExtraTreesclassifier

# %%
 from sklearn.ensemble import ExtraTreesClassifier
 import matplotlib.pyplot as plt
 model=ExtraTreesClassifier()
 model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
rank=pd.Series(model.feature_importances_,index=X.columns)
rank.nlargest().plot(kind='barh')
# Out:
# <Axes: >
